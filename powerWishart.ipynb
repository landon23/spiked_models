# %%
import matplotlib.pyplot as plt
import numpy as np
import main
import imp
imp.reload(main)
N = 8000
M = 8000
p0 = 2/N


S = main.power(N, M, p0)
#trimS = S
#lam, sig = main.params(np.mean(trimS), np.mean(trimS*trimS))
#print('lambda:', lam, 'sigma:', sig)
#x, y = main.plotWiki(100,lam, sig)
#plt.plot(x, y)
plt.hist(S, bins=100, density=True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import main
import imp
imp.reload(main)

N = 500
M = 5000
p0 = 0.2/N
#N=250
#N=1000

#S = main.power(N, M, p0, p1=N*p0/5)
S = main.power(N, M, p0, p1=0.01)
for i in range(100):
#print(len(S))
    dd = main.power(N, M, p0, p1=0.01)
    S = np.append(S, dd)
trimS = S
#lam, sig = main.params(np.mean(trimS), np.mean(trimS*trimS))
#print('lambda:', lam, 'sigma:', sig)
#x, y = main.plotWiki(100,lam, sig)
#print(x)
#plt.plot(x, y)
#trimS = S
#lam, sig = main.params(np.mean(trimS), np.mean(trimS*trimS))
#print('lambda:', lam, 'sigma:', sig)
#x, y = main.plotWiki(100,lam, sig)
#plt.plot(x, y)
plt.hist(S, bins=50, density=True)

plt.show()

# %%
trimS = S[0:1950]
lam, sig = main.params(np.mean(trimS), np.mean(trimS*trimS))
print('lambda:', lam, 'sigma:', sig)
x, y = main.plotWiki(100,lam, sig)
#print(x)
plt.plot(x, y)
#trimS = S
#lam, sig = main.params(np.mean(trimS), np.mean(trimS*trimS))
#print('lambda:', lam, 'sigma:', sig)
#x, y = main.plotWiki(100,lam, sig)
#plt.plot(x, y)
plt.hist(S, bins=50, density=True)

plt.show()
# Out:
# lambda: 0.1909767127395079 sigma: 3.1830439525996868
