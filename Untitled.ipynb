# %%
import matplotlib.pyplot as plt
import numpy as np
import power
import imp
imp.reload(power)

N = 5000
beta = 0.1 # beta = 0.1, eps=0.01 , N = 5000, is an illustrative choice
eps = 0.01
p = np.power(N, 1-2*beta)*eps

D, V, H = power.power(N, beta, p)
plt.hist(D, bins=100, density=True)
plt.show()

# %%
plt.hist(D, bins=100, density=True)

imp.reload(power)
x, s = power.wig()
plt.plot(x, s)
plt.show()

# %%
v = V[:, 2]
plt.plot(np.arange(N), np.abs(v))

# %%
imp.reload(power)

N = 5000

beta = 3.5
d = np.power(N, 0.4)
#

m = d*d*np.power(N, 0.1)
#m=d
D, V, H = power.chung(N, beta, m, d)
plt.hist(D, bins=100, density=True)
plt.show()

# %%
imp.reload(power)

D, V, H = power.addit(N, 0.6, beta, m, d)
plt.hist(D, bins=100, density=True)
#plt.plot(x, s)
plt.show()
